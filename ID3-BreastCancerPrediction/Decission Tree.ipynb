# %% [markdown]
# # ID3
#     Danae Sánchez
#     María Castañeda
#     Mariana Heredia
#     Mario Carranza

# %%
import csv
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Variables Globales

# %%
dia = csv.excel()
df = pd.read_csv("breast-cancer.txt") 
clase=[x[0] for x in df[['class']].values.tolist()]
nombresAtt=('age','menopause','tumor-size','inv-nodes','deg-mailig','breast','breast-quad','irradiat')
atributos=[df[[nombre]] for nombre in nombresAtt]
atributosL=[]
[atributosL.append([x[0] for x in a.values.tolist()]) for a in atributos]
tot=float(len(np.asarray(atributos[0])))
arbol=[]
flag='true'
df
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4    no-recurrence-events  40-49   premeno        0-4       0-2        no
# 5    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 6    no-recurrence-events  50-59   premeno      25-29       0-2        no
# 7    no-recurrence-events  60-69      ge40      20-24       0-2        no
# 8    no-recurrence-events  40-49   premeno      50-54       0-2        no
# 9    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 10   no-recurrence-events  40-49   premeno        0-4       0-2        no
# 11   no-recurrence-events  50-59      ge40      25-29       0-2        no
# 12   no-recurrence-events  60-69      lt40      10-14       0-2        no
# 13   no-recurrence-events  50-59      ge40      25-29       0-2        no
# 14   no-recurrence-events  40-49   premeno      30-34       0-2        no
# 15   no-recurrence-events  60-69      lt40      30-34       0-2        no
# 16   no-recurrence-events  40-49   premeno      15-19       0-2        no
# 17   no-recurrence-events  50-59   premeno      30-34       0-2        no
# 18   no-recurrence-events  60-69      ge40      30-34       0-2        no
# 19   no-recurrence-events  50-59      ge40      30-34       0-2        no
# 20   no-recurrence-events  50-59      ge40      40-44       0-2        no
# 21   no-recurrence-events  60-69      ge40      15-19       0-2        no
# 22   no-recurrence-events  30-39   premeno      25-29       0-2        no
# 23   no-recurrence-events  50-59   premeno      40-44       0-2        no
# 24   no-recurrence-events  50-59   premeno      35-39       0-2        no
# 25   no-recurrence-events  40-49   premeno      25-29       0-2        no
# 26   no-recurrence-events  50-59   premeno      20-24       0-2        no
# 27   no-recurrence-events  60-69      ge40      25-29       0-2        no
# 28   no-recurrence-events  40-49   premeno      40-44       0-2        no
# 29   no-recurrence-events  60-69      ge40      30-34       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 256     recurrence-events  40-49   premeno      30-34       0-2        no
# 257     recurrence-events  40-49   premeno      20-24       3-5       yes
# 258     recurrence-events  50-59      ge40      30-34       6-8       yes
# 259     recurrence-events  50-59      ge40      30-34       3-5        no
# 260     recurrence-events  60-69      ge40      25-29       3-5        no
# 261     recurrence-events  40-49      ge40      25-29     12-14       yes
# 262     recurrence-events  60-69      ge40      25-29       0-2        no
# 263     recurrence-events  50-59      lt40      20-24       0-2         ?
# 264     recurrence-events  50-59      lt40      20-24       0-2         ?
# 265     recurrence-events  30-39   premeno      35-39      9-11       yes
# 266     recurrence-events  40-49   premeno      30-34       3-5       yes
# 267     recurrence-events  60-69      ge40      20-24     24-26       yes
# 268     recurrence-events  30-39   premeno      35-39       0-2        no
# 269     recurrence-events  40-49   premeno      25-29       0-2        no
# 270     recurrence-events  50-59      ge40      30-34       6-8       yes
# 271     recurrence-events  50-59   premeno      25-29       0-2        no
# 272     recurrence-events  40-49   premeno      15-19       0-2       yes
# 273     recurrence-events  60-69      ge40      30-34       0-2       yes
# 274     recurrence-events  60-69      ge40      30-34       3-5       yes
# 275     recurrence-events  40-49   premeno      25-29      9-11       yes
# 276     recurrence-events  30-39   premeno      25-29       6-8       yes
# 277     recurrence-events  60-69      ge40      10-14       6-8       yes
# 278     recurrence-events  50-59   premeno      35-39     15-17       yes
# 279     recurrence-events  50-59      ge40      40-44       6-8       yes
# 280     recurrence-events  50-59      ge40      40-44       6-8       yes
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34       3-5        no
# 285     recurrence-events  50-59      ge40      30-34       3-5        no
#
#      deg-mailig breast breast-quad irradiat
# 0             3   left    left_low       no
# 1             2  right    right_up       no
# 2             2   left    left_low       no
# 3             2  right     left_up       no
# 4             2  right   right_low       no
# 5             2   left    left_low       no
# 6             2   left    left_low       no
# 7             1   left    left_low       no
# 8             2   left    left_low       no
# 9             2  right     left_up       no
# 10            3   left     central       no
# 11            2   left    left_low       no
# 12            1   left    right_up       no
# 13            3   left    right_up       no
# 14            3   left     left_up       no
# 15            1   left    left_low       no
# 16            2   left    left_low       no
# 17            3   left    left_low       no
# 18            3   left    left_low       no
# 19            1  right    right_up       no
# 20            2   left    left_low       no
# 21            2   left    left_low       no
# 22            2  right    left_low       no
# 23            2   left     left_up       no
# 24            2  right     left_up       no
# 25            2   left     left_up       no
# 26            1   left    left_low       no
# 27            3  right     left_up       no
# 28            2  right    left_low       no
# 29            2   left    left_low       no
# ..          ...    ...         ...      ...
# 256           1   left    left_low      yes
# 257           2   left    left_low      yes
# 258           2   left   right_low      yes
# 259           3  right     left_up       no
# 260           2  right    right_up       no
# 261           3   left   right_low      yes
# 262           3   left     left_up       no
# 263           1   left     left_up       no
# 264           1   left    left_low       no
# 265           3   left    left_low       no
# 266           2   left    right_up       no
# 267           3   left    left_low      yes
# 268           3   left    left_low       no
# 269           2   left    left_low      yes
# 270           3   left   right_low       no
# 271           3  right    left_low      yes
# 272           3  right     left_up       no
# 273           2  right    right_up      yes
# 274           2   left     central      yes
# 275           3  right     left_up       no
# 276           3   left   right_low      yes
# 277           3   left     left_up      yes
# 278           3  right    right_up       no
# 279           3   left    left_low      yes
# 280           3   left    left_low      yes
# 281           2   left     left_up       no
# 282           3   left     left_up      yes
# 283           1  right     left_up       no
# 284           3   left    left_low       no
# 285           3   left    left_low       no
#
# [286 rows x 10 columns]

# %%
classesN = {
    'class': ['no-recurrence-events','recurrence-events'],
    'age': ['20-29','30-39','40-49','50-59','60-69','70-79'],
    'menopause':['It-40','ge40','premeno'],
    'tumor-size':['0-4','15-19','20-24','25-29','30-34','35-39','40-44','45-49','50-54','10-14','5-9','05-19'],
    'inv-nodes': ['0-2','12-14','15-17','24-26','3-5','6-8','9-11'],
    ' node-caps': ['yes', 'no'],
    'deg-mailig':[1,2,3],
    'breast': ['left','right'],
    'breast-quad':['?','central','left_low','left_up','right_low','right_up'],
    'irradiat':['yes','no']
    }   
sn=classesN['class'][0]
ss=classesN['class'][1]

# %% [markdown]
# ##  Funciones Auxiliares

# %%
#cuenta cuántos de cada atributo 
col=[x[0] for x in atributos[0].values.tolist()]
def cuantosPorclase (col):
    return dict([(x, col.count(x)) for x in col])
#cpcA=cuantosPorclase(atributosL[0])

# %%
def cuantosDadoClase(col1,col2):
    l=zip(col1,col2)
    k = [(x, l.count(x)) for x in l]
    return dict(k)
#cdcA=cuantosDadoClase(atributosL[0],clase)

# %%
# entropia
def entropia (cpc,cdc,clases):
    e=0
    for s in cpc:
        sn=(s,clases[0])
        ss=(s,clases[1])
        td=float(cpc[s])
        #print cdc
        if(ss in cdc.keys() and sn in cdc.keys()):
            e=e+cpc[s]/tot*(-1)*(cdc[ss]/td*math.log(float(cdc[ss])/td,2)+cdc[sn]/td*math.log(float(cdc[sn])/td,2))
            #print 'calculando entropia'
        
    return e
#entropia(cpcA,cdcA,[sn,ss])

# %%
#menor entropia
from operator import itemgetter
def minEntropia (attributes,names,target,classes):
    ent=[]
    i=0
    if(attributes):
        for at in attributes:
            cpcAt=cuantosPorclase(at)
            cdcAt=cuantosDadoClase(at,target)
            ent.append([entropia(cpcAt,cdcAt,classes),names[i]])
            i=i+1
    
        res=min(ent,key=itemgetter(0))[0],min(ent,key=itemgetter(0))[1],[x[0] for x in df[[min(ent,key=itemgetter(0))[1]]].values.tolist()]
    else:
        res=0,'indef',[]
    return res
#[minH,nomMinH,listMinH]=minEntropia(atributosL,nombresAtt,clase,[sn,ss])

# %%
#tabla sin el ganador
def nuevaTabla (nombreAtributo,nombresAtts):
    atributosN,nombres=[],[]
    for n in nombresAtts:
        if(n != nombreAtributo):
             atributosN.append([x[0] for x in df[[n]].values.tolist()])
             nombres.append(n)
                
    atributosN.append(clase)
    return [np.array(atributosN), nombres]

#[atts,noms]=nuevaTabla(me[1],nombresAtt)

# %%
#tabla dado un atributo del ganador
#att=classes[nomMinH][0]
def tablaDadoHijo(hijo,attsSinMinH,listMinH):
    tabla=[]
    for x in range(len(listMinH)):
        if(listMinH[x]==hijo):
            tabla.append([attsSinMinH[k][x] for k in range(len(attsSinMinH))])
    
    clase=[tabla[k][len(attsSinMinH)-1] for k in range(len(tabla))]
    tabla=[[tabla[k][x] for k in range(len(tabla))] for x in range(len(attsSinMinH)-1)]
    
    return [tabla,clase]

#[tablaDadoAtt,claseDadoAtt]=tablaDadoHijo(att,atts)

# %% [markdown]
# ##  Función Principal

# %%
nivel=0
arbol=[]
papa=''
file = open("Reglas.txt", "w")
def ID3(attributes,names,target,classes,level,papa):
    
    [minH,nomMinH,listMinH]=minEntropia(attributes,names,target,[classes[0],classes[1]])
    if(nomMinH!='indef'):
        arbol.append([papa,level,nomMinH])
        papa=nomMinH
        level=level+1
        [atts,noms]=nuevaTabla(nomMinH,names)
        k=cuantosDadoClase(listMinH,target)

        for h in classesN[papa]:
            print ''+ ' '*level*5+'Si %s es %s' %(papa,h)
            file.write(''+ ' '*level*5+'Si %s es %s \n' %(papa,h))
            if((h,sn) in k.keys() and (h,ss) in k.keys()):
                [tablaDadoAtt,claseDadoAtt]=tablaDadoHijo(h,atts,listMinH)
                ID3(tablaDadoAtt,noms,claseDadoAtt,[sn,ss],level,papa)
            else:
                if((h,sn) in k.keys()):
                    arbol.append([sn,level,papa])
                    print ''+ ' '*(level+1)*6+'entonces %s' %sn
                    file.write(''+ ' '*(level+1)*6+'entonces %s \n' %sn)

                else:
                    arbol.append([ss,level,papa])
                    print ''+ ' '*(level+1)*6+'entonces %s ' %ss
                    file.write(''+ ' '*(level+1)*6+'entonces %s \n' %sn)
    else:
         print ''+ ' '*(level+1)*6+'entonces indef' 
         file.write(''+ ' '*(level+1)*6+'entonces indef \n')

    return arbol

arb=ID3(atributosL,nombresAtt,clase,[sn,ss],nivel,papa)
file.close()
# Out:
#      Si deg-mailig es 1
#           Si tumor-size es 0-4
#                Si age es 20-29
#                         entonces recurrence-events
#                Si age es 30-39
#                         entonces no-recurrence-events
#                Si age es 40-49
#                         entonces no-recurrence-events
#                Si age es 50-59
#                         entonces no-recurrence-events
#                Si age es 60-69
#                     Si inv-nodes es 0-2
#                          Si breast-quad es ?
#                                     entonces recurrence-events
#                          Si breast-quad es central
#                               Si breast es left
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si menopause es It-40
#                                                       entonces recurrence-events
#                                         Si menopause es ge40
#                                                       entonces indef
#                                         Si menopause es premeno
#                                                       entonces indef
#                               Si breast es right
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es left_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es left_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es right_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es right_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                     Si inv-nodes es 12-14
#                               entonces recurrence-events
#                     Si inv-nodes es 15-17
#                               entonces recurrence-events
#                     Si inv-nodes es 24-26
#                               entonces recurrence-events
#                     Si inv-nodes es 3-5
#                               entonces recurrence-events
#                     Si inv-nodes es 6-8
#                               entonces recurrence-events
#                     Si inv-nodes es 9-11
#                               entonces recurrence-events
#                Si age es 70-79
#                         entonces recurrence-events
#           Si tumor-size es 15-19
#                Si age es 20-29
#                         entonces recurrence-events
#                Si age es 30-39
#                         entonces no-recurrence-events
#                Si age es 40-49
#                     Si inv-nodes es 0-2
#                          Si breast-quad es ?
#                                     entonces recurrence-events
#                          Si breast-quad es central
#                               Si breast es left
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si menopause es It-40
#                                                       entonces recurrence-events
#                                         Si menopause es ge40
#                                                       entonces indef
#                                         Si menopause es premeno
#                                                       entonces indef
#                               Si breast es right
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es left_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es left_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es right_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es right_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                     Si inv-nodes es 12-14
#                               entonces recurrence-events
#                     Si inv-nodes es 15-17
#                               entonces recurrence-events
#                     Si inv-nodes es 24-26
#                               entonces recurrence-events
#                     Si inv-nodes es 3-5
#                               entonces recurrence-events
#                     Si inv-nodes es 6-8
#                               entonces recurrence-events
#                     Si inv-nodes es 9-11
#                               entonces recurrence-events
#                Si age es 50-59
#                     Si inv-nodes es 0-2
#                          Si breast-quad es ?
#                                     entonces recurrence-events
#                          Si breast-quad es central
#                               Si breast es left
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si menopause es It-40
#                                                       entonces recurrence-events
#                                         Si menopause es ge40
#                                                       entonces indef
#                                         Si menopause es premeno
#                                                       entonces indef
#                               Si breast es right
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es left_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es left_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es right_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es right_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                     Si inv-nodes es 12-14
#                               entonces recurrence-events
#                     Si inv-nodes es 15-17
#                               entonces recurrence-events
#                     Si inv-nodes es 24-26
#                               entonces recurrence-events
#                     Si inv-nodes es 3-5
#                               entonces recurrence-events
#                     Si inv-nodes es 6-8
#                               entonces recurrence-events
#                     Si inv-nodes es 9-11
#                               entonces recurrence-events
#                Si age es 60-69
#                     Si inv-nodes es 0-2
#                          Si breast-quad es ?
#                                     entonces recurrence-events
#                          Si breast-quad es central
#                               Si breast es left
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si menopause es It-40
#                                                       entonces recurrence-events
#                                         Si menopause es ge40
#                                                       entonces indef
#                                         Si menopause es premeno
#                                                       entonces indef
#                               Si breast es right
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es left_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es left_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                          Si breast-quad es right_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es right_up
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si menopause es premeno
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                     Si inv-nodes es 12-14
#                               entonces recurrence-events
#                     Si inv-nodes es 15-17
#                               entonces recurrence-events
#                     Si inv-nodes es 24-26
#                               entonces recurrence-events
#                     Si inv-nodes es 3-5
#                               entonces recurrence-events
#                     Si inv-nodes es 6-8
#                               entonces recurrence-events
#                     Si inv-nodes es 9-11
#                               entonces recurrence-events
#                Si age es 70-79
#                         entonces recurrence-events
#           Si tumor-size es 20-24
#                Si menopause es It-40
#                         entonces recurrence-events
#                Si menopause es ge40
#                     Si inv-nodes es 0-2
#                          Si breast-quad es ?
#                                     entonces recurrence-events
#                          Si breast-quad es central
#                               Si age es 20-29
#                                           entonces recurrence-events
#                               Si age es 30-39
#                                           entonces no-recurrence-events
#                               Si age es 40-49
#                                           entonces no-recurrence-events
#                               Si age es 50-59
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                           entonces recurrence-events
#                          Si breast-quad es left_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si age es 20-29
#                                                 entonces no-recurrence-events
#                                    Si age es 30-39
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 40-49
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 50-59
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 60-69
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 70-79
#                                                 entonces no-recurrence-events
#                          Si breast-quad es left_up
#                               Si age es 20-29
#                                           entonces no-recurrence-events
#                               Si age es 30-39
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 40-49
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                               Si age es 50-59
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es right_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si age es 20-29
#                                                 entonces no-recurrence-events
#                                    Si age es 30-39
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 40-49
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 50-59
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 60-69
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 70-79
#                                                 entonces no-recurrence-events
#                          Si breast-quad es right_up
#                               Si age es 20-29
#                                           entonces recurrence-events
#                               Si age es 30-39
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 40-49
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                               Si age es 50-59
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                           entonces recurrence-events
#                     Si inv-nodes es 12-14
#                               entonces recurrence-events
#                     Si inv-nodes es 15-17
#                               entonces recurrence-events
#                     Si inv-nodes es 24-26
#                               entonces recurrence-events
#                     Si inv-nodes es 3-5
#                               entonces recurrence-events
#                     Si inv-nodes es 6-8
#                               entonces recurrence-events
#                     Si inv-nodes es 9-11
#                               entonces recurrence-events
#                Si menopause es premeno
#                     Si inv-nodes es 0-2
#                          Si breast-quad es ?
#                                     entonces recurrence-events
#                          Si breast-quad es central
#                               Si age es 20-29
#                                           entonces recurrence-events
#                               Si age es 30-39
#                                           entonces no-recurrence-events
#                               Si age es 40-49
#                                           entonces no-recurrence-events
#                               Si age es 50-59
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                           entonces recurrence-events
#                          Si breast-quad es left_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si age es 20-29
#                                                 entonces no-recurrence-events
#                                    Si age es 30-39
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 40-49
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 50-59
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 60-69
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 70-79
#                                                 entonces no-recurrence-events
#                          Si breast-quad es left_up
#                               Si age es 20-29
#                                           entonces no-recurrence-events
#                               Si age es 30-39
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 40-49
#                                    Si breast es left
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                                    Si breast es right
#                                         Si irradiat es yes
#                                                       entonces recurrence-events
#                                         Si irradiat es no
#                                                       entonces indef
#                               Si age es 50-59
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                          Si breast-quad es right_low
#                               Si irradiat es yes
#                                           entonces recurrence-events
#                               Si irradiat es no
#                                    Si age es 20-29
#                                                 entonces no-recurrence-events
#                                    Si age es 30-39
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 40-49
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 50-59
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 60-69
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 70-79
#                                                 entonces no-recurrence-events
#                          Si breast-quad es right_up
#                               Si age es 20-29
#                                           entonces recurrence-events
#                               Si age es 30-39
#                                    Si irradiat es yes
#                                                 entonces recurrence-events
#                                    Si irradiat es no
#                                         Si breast es left
# ...
#                               Si age es 70-79
#                                           entonces recurrence-events
#                          Si breast-quad es left_low
#                               Si age es 20-29
#                                           entonces no-recurrence-events
#                               Si age es 30-39
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 40-49
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 50-59
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                    Si breast es left
#                                         Si menopause es It-40
#                                                       entonces recurrence-events
#                                         Si menopause es ge40
#                                                       entonces indef
#                                         Si menopause es premeno
#                                                       entonces indef
#                                    Si breast es right
#                                                 entonces no-recurrence-events
#                          Si breast-quad es left_up
#                               Si age es 20-29
#                                           entonces no-recurrence-events
#                               Si age es 30-39
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 40-49
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 50-59
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                    Si breast es left
#                                         Si menopause es It-40
#                                                       entonces recurrence-events
#                                         Si menopause es ge40
#                                                       entonces indef
#                                         Si menopause es premeno
#                                                       entonces indef
#                                    Si breast es right
#                                                 entonces no-recurrence-events
#                          Si breast-quad es right_low
#                               Si menopause es It-40
#                                           entonces recurrence-events
#                               Si menopause es ge40
#                                    Si age es 20-29
#                                                 entonces no-recurrence-events
#                                    Si age es 30-39
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 40-49
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 50-59
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 60-69
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 70-79
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces no-recurrence-events
#                               Si menopause es premeno
#                                    Si age es 20-29
#                                                 entonces no-recurrence-events
#                                    Si age es 30-39
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 40-49
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 50-59
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 60-69
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si age es 70-79
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces no-recurrence-events
#                          Si breast-quad es right_up
#                               Si age es 20-29
#                                           entonces recurrence-events
#                               Si age es 30-39
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 40-49
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 50-59
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 60-69
#                                    Si menopause es It-40
#                                                 entonces recurrence-events
#                                    Si menopause es ge40
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                                    Si menopause es premeno
#                                         Si breast es left
#                                                       entonces indef
#                                         Si breast es right
#                                                       entonces indef
#                               Si age es 70-79
#                                           entonces recurrence-events
#                Si tumor-size es 5-9
#                         entonces no-recurrence-events
#                Si tumor-size es 05-19
#                         entonces recurrence-events
#           Si inv-nodes es 12-14
#                   entonces recurrence-events
#           Si inv-nodes es 15-17
#                   entonces recurrence-events
#           Si inv-nodes es 24-26
#                   entonces recurrence-events
#           Si inv-nodes es 3-5
#                   entonces recurrence-events
#           Si inv-nodes es 6-8
#                   entonces recurrence-events
#           Si inv-nodes es 9-11
#                   entonces recurrence-events
